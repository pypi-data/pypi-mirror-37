# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.DataFrame({
            'y': [-2, -2.2, -1.8, -1.5, -1, 1, 1.5, 2, 2.2, 1.8],
            'group': ['a', 'a', 'a', 'a', 'a', 'b', 'b', 'b', 'b', 'b']
            })

# %%
from gneiss.plot import balance_histogram
a = balance_histogram(df.y, df.group)

# %%
dir(a)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_text',
#  '_adjustable',
#  '_agg_filter',
#  '_alpha',
#  '_anchor',
#  '_animated',
#  '_aspect',
#  '_autoscaleXon',
#  '_autoscaleYon',
#  '_axes',
#  '_axes_class',
#  '_axes_locator',
#  '_axisbelow',
#  '_cachedRenderer',
#  '_clipon',
#  '_clippath',
#  '_connected',
#  '_contains',
#  '_current_image',
#  '_cursorProps',
#  '_facecolor',
#  '_frameon',
#  '_gci',
#  '_gen_axes_patch',
#  '_gen_axes_spines',
#  '_get_axis_list',
#  '_get_legend_handles',
#  '_get_lines',
#  '_get_patches_for_fill',
#  '_get_view',
#  '_gid',
#  '_gridOn',
# ...

# %%
a.get_lines()[0]._x
# Out:
# array([ 0.14654374,  0.16943281,  0.19232189,  0.21521096,  0.23810004,
#         0.26098911,  0.28387819,  0.30676726,  0.32965634,  0.35254541,
#         0.37543449,  0.39832356,  0.42121264,  0.44410171,  0.46699079,
#         0.48987986,  0.51276894,  0.53565801,  0.55854709,  0.58143616,
#         0.60432524,  0.62721431,  0.65010339,  0.67299246,  0.69588154,
#         0.71877061,  0.74165969,  0.76454876,  0.78743784,  0.81032691,
#         0.83321599,  0.85610506,  0.87899414,  0.90188321,  0.92477229,
#         0.94766136,  0.97055044,  0.99343951,  1.01632859,  1.03921766,
#         1.06210674,  1.08499581,  1.10788489,  1.13077396,  1.15366304,
#         1.17655211,  1.19944119,  1.22233026,  1.24521934,  1.26810841,
#         1.29099749,  1.31388656,  1.33677564,  1.35966471,  1.38255379,
#         1.40544286,  1.42833194,  1.45122101,  1.47411009,  1.49699916,
#         1.51988824,  1.54277731,  1.56566639,  1.58855546,  1.61144454,
# ...

# %%
np.savetxt('test/data/test_coords.txt', a.get_lines()[0]._xy)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-1c0c75b5c2c5> in <module>()
# ----> 1 np.savetxt('test/data/test_coords.txt', a.get_lines()[0]._xy)
#
# ~/miniconda3/envs/pls-balances/lib/python3.5/site-packages/numpy/lib/npyio.py in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments)
#    1094         else:
#    1095             if sys.version_info[0] >= 3:
# -> 1096                 fh = open(fname, 'wb')
#    1097             else:
#    1098                 fh = open(fname, 'w')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test/data/test_coords.txt'
